# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

labels = ["Pass@1", "Pass@2"]
base_model_acc = [0.2904, 0.3108]
reasoning_model_acc = [0.3484, 0.3714]

bar_height = 0.35
gap = 0.10

y_pos_base = [i - bar_height/2 - gap/2 for i in range(len(labels))]
y_pos_reasoning = [i + bar_height/2 + gap/2 for i in range(len(labels))]

fig, ax = plt.subplots(figsize=(10, 3))
ax.barh(y_pos_base, base_model_acc, height=bar_height, color="#74b9ff", label="Base Models")
ax.barh(y_pos_reasoning, reasoning_model_acc, height=bar_height, color="#f78fb3", label="Reasoning Models")

for y, acc in zip(y_pos_base, base_model_acc):
    ax.text(acc - 0.01, y, f"{acc:.4f}", va='center', ha='right', fontsize=16, color="white", fontweight='bold')
for y, acc in zip(y_pos_reasoning, reasoning_model_acc):
    ax.text(acc - 0.01, y, f"{acc:.4f}", va='center', ha='right', fontsize=16, color="white", fontweight='bold')

ax.set_yticks([0, 1])
ax.set_yticklabels(labels, fontsize=16)

ax.xaxis.set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.tick_params(axis='x', which='both', bottom=False, top=False)
ax.tick_params(axis='y', which='both', left=False)

ax.legend(loc='upper left', bbox_to_anchor=(1.02, 1), fontsize=16)
plt.tight_layout()
plt.savefig('avg_base_reason.pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

labels = ["Pass@1", "Pass@2"]
open_model_acc = [0.2999, 0.3214]
close_model_acc = [0.3040, 0.3249]

bar_height = 0.35
gap = 0.10

y_pos_open = [i - bar_height/2 - gap/2 for i in range(len(labels))]
y_pos_close = [i + bar_height/2 + gap/2 for i in range(len(labels))]

fig, ax = plt.subplots(figsize=(10, 3))
ax.barh(y_pos_open, open_model_acc, height=bar_height, color="#74b9ff", label="Open Models")
ax.barh(y_pos_close, close_model_acc, height=bar_height, color="#f78fb3", label="Closed Models")

for y, acc in zip(y_pos_open, open_model_acc):
    ax.text(acc - 0.01, y, f"{acc:.4f}", va='center', ha='right', fontsize=16, color="white", fontweight='bold')
for y, acc in zip(y_pos_close, close_model_acc):
    ax.text(acc - 0.01, y, f"{acc:.4f}", va='center', ha='right', fontsize=16, color="white", fontweight='bold')

ax.set_yticks([0, 1])
ax.set_yticklabels(labels, fontsize=16)

ax.xaxis.set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.tick_params(axis='x', which='both', bottom=False, top=False)
ax.tick_params(axis='y', which='both', left=False)

ax.legend(loc='upper left', bbox_to_anchor=(1.02, 1), fontsize=16)
plt.tight_layout()
plt.savefig('avg_open_close.pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ["Pass@1", "Pass@2"]
accuracies = {
    "OpenAI": [0.3750, 0.3970],
    "Anthropic": [0.3395, 0.3595],
    "DeepSeek": [0.2999, 0.3214],
    "xAI": [0.2714, 0.2896],
    "Google": [0.1512, 0.1735],
}

colors = {
    "OpenAI": "#3d9eff",
    "Anthropic": "#f78fb3",
    "DeepSeek": "#74b9ff",
    "xAI": "#f7c0d3",
    "Google": "#9dcdfeff",
}

sorted_models = sorted(accuracies.items(), key=lambda x: np.mean(x[1]), reverse=True)

bar_height = 0.12
gap = 0.02
n_models = len(sorted_models)
n_labels = len(labels)

fig, ax = plt.subplots(figsize=(10, 8))

for i, (model, accs) in enumerate(sorted_models):
    y_positions = [j + ((n_models - 1 - i) - n_models / 2) * (bar_height + gap) for j in range(n_labels)]
    ax.barh(y_positions, accs, height=bar_height, label=model, color=colors[model])

    for y, acc in zip(y_positions, accs):
        ax.text(acc - 0.01, y, f"{acc:.4f}", va='center', ha='right',
                fontsize=16, color="white", fontweight='bold')

ax.set_yticks([i for i in range(n_labels)])
ax.set_yticklabels(labels, fontsize=16)

ax.xaxis.set_visible(False)
for spine in ['top', 'bottom', 'left', 'right']:
    ax.spines[spine].set_visible(False)

ax.tick_params(axis='y', left=False)
ax.legend(loc='upper left', bbox_to_anchor=(1.02, 1), fontsize=16)

plt.tight_layout()
plt.savefig('avg_provider_wise.pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define labels and data
labels = ["Pass@1", "Pass@2"]
accuracies = {
    "OpenAI": [0.4321, 0.4557],
    "Anthropic": [0.4185, 0.4429],
    "DeepSeek": [0.3165, 0.3384],
    "xAI": [0.4005, 0.4312],
    "Google": [0.2351, 0.2789],
}

# Map detailed model names
model_names = {
    "OpenAI": "gpt-4o",
    "Anthropic": "claude-opus-4-thinking",
    "DeepSeek": "deepseek-r1",
    "xAI": "o3-pro",
    "Google": "gemini-ultra",
}

colors = {
    "OpenAI": "#3d9eff",
    "Anthropic": "#f78fb3",
    "DeepSeek": "#74b9ff",
    "xAI": "#f7c0d3",
    "Google": "#9dcdfeff",
}

# Sort models by average accuracy
sorted_models = sorted(accuracies.items(), key=lambda x: np.mean(x[1]), reverse=True)

# Layout settings
bar_height = 0.12
gap = 0.02
n_models = len(sorted_models)
n_labels = len(labels)

fig, ax = plt.subplots(figsize=(10, 8))

# Draw bars and add annotations
for i, (model, accs) in enumerate(sorted_models):
    y_positions = [j + ((n_models - 1 - i) - n_models / 2) * (bar_height + gap) for j in range(n_labels)]
    ax.barh(y_positions, accs, height=bar_height, label=model, color=colors[model])

    for y, acc in zip(y_positions, accs):
        # Accuracy label
        ax.text(acc - 0.01, y, f"{acc:.4f}", va='center', ha='right',
                fontsize=16, color="white", fontweight='bold')

        # Model name inside bar with Source Code Pro font
        ax.text(0.01, y, model_names[model], va='center', ha='left',
                fontsize=16, color="black", fontweight='bold', family='Source Code Pro')

# Y-axis settings
ax.set_yticks([i for i in range(n_labels)])
ax.set_yticklabels(labels, fontsize=16)

# Remove spines and ticks
ax.xaxis.set_visible(False)
for spine in ['top', 'bottom', 'left', 'right']:
    ax.spines[spine].set_visible(False)
ax.tick_params(axis='y', left=False)

# Legend
ax.legend(loc='upper left', bbox_to_anchor=(1.02, 1), fontsize=16)

plt.tight_layout()
plt.savefig('top_models_provider_wise.pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ["OpenAI", "Anthropic", "DeepSeek", "xAI", "Google"]
colors = ["#3d9eff", "#f78fb3", "#74b9ff", "#f7c0d3", "#9dcdfe"]

q1 = [207, 231, 207, 193, 161]
q2 = [132,  79,  22,  88,   3]
q3 = [  8,  12,   1,   5,   3]

totals = [240, 240, 240]

quarters = []
for raw_counts, total in zip([q1, q2, q3], totals):
    raw_props = [v / total for v in raw_counts]
    s = sum(raw_props)
    quarters.append([v / s for v in raw_props] if s > 0 else None)

titles = ["Quartile I", "Quartile II", "Quartile III"]

fig = plt.figure(figsize=(10, 8))
gs = fig.add_gridspec(2, 2, height_ratios=[1, 1])

ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])

ax3 = fig.add_subplot(gs[1, :])

axes = [ax1, ax2, ax3]

for ax, title, data in zip(axes, titles, quarters):
    wedges, texts, autotexts = ax.pie(
        data,
        labels=labels,
        colors=colors,
        autopct=lambda pct: f"{pct:.1f}%",
        startangle=90,
        textprops={"fontsize": 16}
    )
    for autotext in autotexts:
        autotext.set_color("white")
        autotext.set_fontweight("bold")
    for text in texts:
        text.set_fontweight("normal")
    ax.set_title(title, fontsize=16, fontweight="bold")
    
plt.tight_layout()
plt.savefig('quartile_provider_wise_pie.pdf', dpi=300)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_path = 'project_euler_problems.csv'
df = pd.read_csv(file_path)

df_sorted = df.sort_values('solvers', ascending=True)
quartile_dfs = np.array_split(df_sorted, 4)

labels = df['Topic'].unique().tolist()
colors = ["#256cb2", "#f78fb3", "#74b9ff", "#f7c0d3", "#9dcdfe", "#c36385", "#fd347a", "#757373", "#0080ff"]

quarters = []
for qdf in quartile_dfs:
    counts = qdf['Topic'].value_counts().reindex(labels, fill_value=0).tolist()
    total = len(qdf)
    props = [c / total for c in counts]
    s = sum(props)
    quarters.append([v / s for v in props])

titles = [
    "Quartile I",
    "Quartile II",
    "Quartile III",
    "Quartile IV"
]

pct_threshold = 5.0

def make_autopct(threshold):
    def autopct(pct):
        return f"{pct:.1f}%" if pct >= threshold else ""
    return autopct

fig = plt.figure(figsize=(10, 8))
gs = fig.add_gridspec(2, 2)

axes = [
    fig.add_subplot(gs[0, 0]),
    fig.add_subplot(gs[0, 1]),
    fig.add_subplot(gs[1, 0]),
    fig.add_subplot(gs[1, 1]),
]

for ax, title, data in zip(axes, titles, quarters):
    wedges, _, autotexts = ax.pie(
        data,
        labels=None,
        colors=colors[:len(labels)],
        startangle=30,
        autopct=make_autopct(pct_threshold),
        textprops={"fontsize": 16, "fontweight": "bold"}
    )
    for at in autotexts:
        if at.get_text():
            at.set_color("white")
    ax.set_title(title, fontsize=16, fontweight="bold")

fig.legend(
    wedges,
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.05),
    ncol=4,
    title="Topic",
    frameon=False,
    fontsize=16,
    title_fontsize=16
)

plt.tight_layout(rect=[0, 0.05, 1, 1])
plt.savefig(
    'quartile_topic_distribution.pdf',
    dpi=300,
    bbox_inches='tight'
)
plt.show()
# Out:
# C:\Users\Anurag Dutta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
